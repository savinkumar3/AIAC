# %% [markdown]
# <a href="https://colab.research.google.com/github/savinkumar3/AIAC/blob/main/Chapter_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# removes the existing version of the transformers library.

# !pip uninstall -y transformers
# Installs a specific version (4.46.3) along with its required libraries.
# !pip install -U transformers==4.46.3 \
                accelerate \
                sentencepiece \
                huggingface-hub==0.26.2

# %%
# Import Model and Tokenizer from the transformers library
from transformers import AutoModelForCausalLM, AutoTokenizer

# Loads the Phi-3 language model
model = AutoModelForCausalLM.from_pretrained("microsoft/Phi-3-mini-4k-instruct",
     # Use the GPU
    device_map="cuda",
    # Choose the best data type automatically
    torch_dtype="auto",
     # Allow the model to run its own code
    trust_remote_code=True,
)

# Load the tokenizer for the model
tokenizer = AutoTokenizer.from_pretrained(
    "microsoft/Phi-3-mini-4k-instruct"
)

# %%
# Import pipeline , which Combines the model and tokenizer  to generate the output
from transformers import pipeline
# Create a pipeline
generator = pipeline(
# Tells the pipeline to perform text generation task
"text-generation",
# Uses model that we are imported (Phi-3)
model=model,
# Uses the tokenizer that convert text into tokens and tokens to text =
tokenizer=tokenizer,
# return only newly generated text (Avoid the original prompt )
return_full_text=
False
,
# Allow the model to generate only 500 new tokens(words)
max_new_tokens=500,
# Tells the model to generate the specific(next) text (No randomness)
do_sample=
False
)

# %%
# The prompt (user input / query)
messages = [{"role": "user", "content": "Create a funny joke about chickens."}
]
# Generate output
output = generator(messages)
print(output[0]["generated_text"])
# Out:
# The `seen_tokens` attribute is deprecated and will be removed in v4.41. Use the `cache_position` model input instead.
# `get_max_cache()` is deprecated for all Cache classes. Use `get_max_cache_shape()` instead. Calling `get_max_cache()` will raise error from v4.48
# WARNING:transformers_modules.microsoft.Phi-3-mini-4k-instruct.f39ac1d28e925b323eae81227eaba4464caced4e.modeling_phi3:You are not running the flash-attention implementation, expect numerical differences.
#  Why did the chicken join the band? Because it had the drumsticks!
